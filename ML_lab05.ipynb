# %% [markdown]
# <a href="https://colab.research.google.com/github/Sinyoung3016/MachineLearning_Tutorial/blob/master/ML_lab05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##binary classification
import tensorflow as tf

#1.dataSet 설정
x_data = [[1, 2],[2, 3],[3, 1],[4, 3],[5, 3],[6, 2]]
y_data = [[0], [0], [0], [1], [1], [1]]

#2.Model 구성
tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=2))
tf.model.add(tf.keras.layers.Activation('sigmoid'))

#3. Model 학습과정 설정
tf.model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.SGD(lr=0.01), metrics=['accuracy'])

#4. Model 출력
tf.model.summary()

#5. Model 학습
history = tf.model.fit(x_data, y_data, epochs=100)#return np.array

#6. Model 사용하기
print("Accuracy: ", history.history['accuracy'][-1])

# %%
import tensorflow as tf
import numpy as np

#dataSet 설정
x_train = [1,2,3,4]
y_train = [1,2,3,4]

#Model 구성
model = tf.keras.models.Sequential()
  #units == output shape, input_dim = input shape
model.add(tf.keras.layers.Dense(units=1, input_dim=1)) #add로 layer쌓기

#Model의 학습과정 설정
  #mse = mean square error
  #sgd = stadard gradient descent
sgd = tf.keras.optimizers.SGD(lr=0.1)
model.compile(loss='mse', optimizer=sgd, metrics=['acc'])

#Model 학습
train = model.fit(x_train, y_train, epochs=100)

import tensorflow as tf
import numpy as np

#dataSet 설정
x_train = [1,2,3,4]
y_train = [1,2,3,4]

#Model 구성
model = tf.keras.models.Sequential()
  #units == output shape, input_dim = input shape
model.add(tf.keras.layers.Dense(units=1, input_dim=1)) #add로 layer쌓기

#Model의 학습과정 설정
  #mse = mean square error
  #sgd = stadard gradient descent
sgd = tf.keras.optimizers.SGD(lr=0.1)
model.compile(loss='mse', optimizer=sgd, metrics=['acc'])

#Model 학습
train = model.fit(x_train, y_train, epochs=100)

#Model 학습 과정 보기
print("##training loss and acc##")
print(train.history['loss'])
print(train.history['acc'])

"""
#Model평가
print("##evaluation##")
eva = model.evaluate()
print(eva)
"""

#Model 예측
print("##y_test##")
y_test = model.predict(np.array([4,6,7]))
print(y_test)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4117 - acc: 0.2500
# Epoch 2/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1852 - acc: 0.2500
# Epoch 3/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0836 - acc: 0.2500
# Epoch 4/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0379 - acc: 0.2500
# Epoch 5/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0174 - acc: 0.2500
# Epoch 6/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0081 - acc: 0.2500
# Epoch 7/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0040 - acc: 0.2500
# Epoch 8/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0021 - acc: 0.2500
# Epoch 9/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012 - acc: 0.2500
# Epoch 10/100
# 1/1 [==============================] - 0s 1ms/step - loss: 7.9753e-04 - acc: 0.2500
# Epoch 11/100
# ...

# %%
##### Version01 #####
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
##
x_data = [[1, 2],[2, 3],[3, 1],[4, 3],[5, 3],[6, 2]]
y_data = [[0], [0], [0], [1], [1], [1]]

X = tf.placeholder(tf.float32, shape = [None, 2])#N = 6
Y = tf.placeholder(tf.float32, shape = [None, 1])#N = 6

W = tf.Variable(tf.random_normal([2, 1]), name = 'w')
b = tf.Variable(tf.random_normal([1]),  name = 'b')

hypothesis = tf.sigmoid(tf.matmul(X, W) + b)#sigmoid = s자형 함수
# = tf.div(1., 1. + tf.exp( -(tf.matmul(X, W) + b) ))

cost = -tf.reduce_mean( Y * tf.log(hypothesis) + (1-Y) * tf.log(1 - hypothesis) )
train = tf.train.GradientDescentOptimizer(learning_rate  = 0.01).minimize(cost)

predicted = tf.cast(hypothesis > 0.5, dtype = tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype = tf.float32))

with tf.Session() as sess:
  sess.run(tf.global_variables_initializer())

  for step in range(10001):
    cost_val, _ = sess.run([cost, train], feed_dict = {X : x_data, Y : y_data})
    if step % 200 == 0:
      print(step, cost_val)

  h, c, a = sess.run([hypothesis, predicted, accuracy], feed_dict = {X : x_data, Y : y_data})
  print("\nHypothesis : ", h, "\nCorrect (Y) : ", c, "\nAccuracy : ", a)
# Out:
# 0 2.2921958
# 200 0.5308282
# 400 0.4999338
# 600 0.47817847
# 800 0.4585911
# 1000 0.44079673
# 1200 0.42447677
# 1400 0.40937623
# 1600 0.39530015
# 1800 0.38210276
# 2000 0.3696755
# 2200 0.35793665
# 2400 0.34682354
# 2600 0.33628544
# 2800 0.32628068
# 3000 0.31677333
# 3200 0.30773157
# 3400 0.29912683
# 3600 0.29093277
# 3800 0.28312498
# 4000 0.27568093
# 4200 0.26857948
# 4400 0.26180074
# 4600 0.25532612
# 4800 0.24913831
# 5000 0.24322085
# 5200 0.23755856
# 5400 0.23213704
# 5600 0.22694272
# 5800 0.22196311
# 6000 0.21718651
# 6200 0.21260154
# 6400 0.20819809
# 6600 0.20396636
# 6800 0.19989727
# 7000 0.19598223
# 7200 0.19221324
# 7400 0.18858288
# 7600 0.18508399
# 7800 0.18170995
# 8000 0.17845471
# 8200 0.1753123
# 8400 0.17227717
# 8600 0.16934432
# 8800 0.16650878
# 9000 0.16376597
# 9200 0.16111164
# 9400 0.1585417
# 9600 0.15605237
# 9800 0.15364006
# 10000 0.15130132
#
# Hypothesis :  [[0.03150284]
#  [0.1598647 ]
#  [0.30850315]
#  [0.7797277 ]
# ...
